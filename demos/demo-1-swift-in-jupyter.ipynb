// %% [markdown]
// ## 第一步

// %%
let pi = 3.14
let y = [1, 2, 3]
print("欢迎来到 Google Developer Days！")
// Out:
// 欢迎来到 Google Developer Days！

// %%
let someNumbers = [
        "Prime": [2, 3, 5, 7, 11, 13],
    "Fibonacci": [1, 1, 2, 3, 5, 8],
       "Square": [1, 4, 9, 16, 25],
]

for (kind, numbers) in someNumbers {
    var largest = 0
    for x in numbers where x > largest && x.isEven {
        largest = x
    }
    print("The largest even \(kind) is \(largest)")
}
// Out:
// error: <Cell 4>:9:45: error: value of type 'Int' has no member 'isEven'
//     for x in numbers where x > largest && x.isEven {
//                                           ~ ^~~~~~

// %% [markdown]
// ## Tensor 库

// %%
import TensorFlow

let x: Tensor<Float> = [[[1, 2], [4, 5]]]

print("x + x =\n\(x + x)\n")
print("sum = \(x.sum())")
print("stddev = \(x.standardDeviation(squeezingAxes: 0, 1))")
// Out:
// x + x =
// [[[ 2.0,  4.0],
//   [ 8.0, 10.0]]]
//
// sum = 12.0
// stdev = [1.5, 1.5]

// %% [markdown]
// ## 深度学习

// %%
var model = Sequential {
    Conv2D<Float>(filterShape: (5, 5, 3, 6))
    MaxPool2D<Float>(poolSize: (2, 2), strides: (2, 2))
    Flatten<Float>()
    Dense<Float>(inputSize: 36 * 6, outputSize: 10)
}

// %%
// Use random training data.
let x = Tensor<Float>(randomNormal: [10, 16, 16, 3])
let y = Tensor<Int32>(rangeFrom: 0, to: 10, stride: 1)

// %%
let optimizer = SGD(for: model)
Context.local.learningPhase = .training

// %%
for i in 1...10 {
    let (loss, grads) = valueWithGradient(at: model) { model -> Tensor<Float> in
        let logits = model(x)
        return softmaxCrossEntropy(logits: logits, labels: y)
    }
    print("Step \(i), loss is: \(loss)")
    optimizer.update(&model.allDifferentiableVariables, along: grads)
}
// Out:
// Step 1, loss is: 3.7474093
// Step 2, loss is: 3.4338384
// Step 3, loss is: 3.1500168
// Step 4, loss is: 2.8914661
// Step 5, loss is: 2.6535168
// Step 6, loss is: 2.4347942
// Step 7, loss is: 2.2348275
// Step 8, loss is: 2.0508156
// Step 9, loss is: 1.8810368
// Step 10, loss is: 1.7250845

// %%
struct Model: Layer {
    var conv = Conv2D<Float>(filterShape: (5, 5, 3, 6))
    var maxPool = MaxPool2D<Float>(poolSize: (2, 2), strides: (2, 2))
    var flatten = Flatten<Float>()
    var dense = Dense<Float>(inputSize: 36 * 6, outputSize: 10)

    @differentiable
    func callAsFunction(_ input: Tensor<Float>) -> Tensor<Float> {
        return dense(flatten(maxPool(conv(input))))
    }
}
